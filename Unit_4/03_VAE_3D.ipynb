# %% [markdown]
# # Variational Autoencoder with 3D Latent Space
#
# Same VAE recipe as `02_VAE_2D.ipynb` but with `z_dim = 3`. Compares against the
# plain AE from `01_FC_Autoencoder_3D.ipynb`.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cpu

# %%
bs = 100
train_dataset = datasets.MNIST(root="./data/", train=True, download=True, transform=transforms.ToTensor())
test_dataset = datasets.MNIST(root="./data/", train=False, download=True, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=bs, shuffle=False)
print(f"Train: {len(train_dataset)}, Test: {len(test_dataset)}")
# Out:
# Train: 60000, Test: 10000

# %% [markdown]
# ## 1. Model

# %%
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim1, h_dim2, z_dim):
        super().__init__()
        # encoder part
        self.fc1 = nn.Linear(x_dim, h_dim1)
        self.fc2 = nn.Linear(h_dim1, h_dim2)
        self.fc31 = nn.Linear(h_dim2, z_dim)
        self.fc32 = nn.Linear(h_dim2, z_dim)
        # decoder part
        self.fc4 = nn.Linear(z_dim, h_dim2)
        self.fc5 = nn.Linear(h_dim2, h_dim1)
        self.fc6 = nn.Linear(h_dim1, x_dim)

    def encoder(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        return self.fc31(h), self.fc32(h)  # mu, log_var

    def sampling(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)

    def decoder(self, z):
        h = F.relu(self.fc4(z))
        h = F.relu(self.fc5(h))
        return torch.sigmoid(self.fc6(h))

    def forward(self, x):
        mu, log_var = self.encoder(x.view(-1, 784))
        z = self.sampling(mu, log_var)
        return self.decoder(z), mu, log_var


vae = VAE(x_dim=784, h_dim1=512, h_dim2=256, z_dim=3).to(device)
print(vae)
# Out:
# VAE(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc31): Linear(in_features=256, out_features=3, bias=True)
#   (fc32): Linear(in_features=256, out_features=3, bias=True)
#   (fc4): Linear(in_features=3, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=512, bias=True)
#   (fc6): Linear(in_features=512, out_features=784, bias=True)
# )

# %% [markdown]
# ## 2. Loss and Optimizer

# %%
optimizer = optim.Adam(vae.parameters())

def loss_function(recon_x, x, mu, log_var):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction="sum")
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return BCE + KLD

# %% [markdown]
# ## 3. Training

# %%
def train(epoch):
    vae.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()

        recon_batch, mu, log_var = vae(data)
        loss = loss_function(recon_batch, data, mu, log_var)

        loss.backward()
        train_loss += loss.item()
        optimizer.step()

        if batch_idx % 100 == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print("====> Epoch: {} Average loss: {:.4f}".format(epoch, train_loss / len(train_loader.dataset)))


def test():
    vae.eval()
    test_loss = 0
    with torch.no_grad():
        for data, _ in test_loader:
            data = data.to(device)
            recon, mu, log_var = vae(data)
            test_loss += loss_function(recon, data, mu, log_var).item()
    test_loss /= len(test_loader.dataset)
    print("====> Test set loss: {:.4f}".format(test_loss))

# %%
for epoch in range(1, 31):
    train(epoch)
    test()

torch.save(vae.state_dict(), "fc_vae_3d.pth")
print("Saved fc_vae_3d.pth")
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 135.104688
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 126.130684
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 129.693652
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 133.441846
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 131.052188
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 133.858350
# ====> Epoch: 1 Average loss: 130.9992
# ====> Test set loss: 131.7402
# Train Epoch: 2 [0/60000 (0%)]	Loss: 130.305049
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 131.445693
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 132.024082
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 128.999336
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 132.625820
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 127.434365
# ====> Epoch: 2 Average loss: 130.4173
# ====> Test set loss: 131.2340
# Train Epoch: 3 [0/60000 (0%)]	Loss: 140.098115
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 131.072119
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 127.208643
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 123.277432
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 129.452773
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 132.405771
# ====> Epoch: 3 Average loss: 129.8756
# ====> Test set loss: 131.0127
# Train Epoch: 4 [0/60000 (0%)]	Loss: 134.865498
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 129.886895
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 122.343838
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 140.007061
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 128.023457
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 133.481328
# ====> Epoch: 4 Average loss: 129.4744
# ====> Test set loss: 131.1227
# Train Epoch: 5 [0/60000 (0%)]	Loss: 129.156660
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 122.335830
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 122.757490
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 131.304346
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 127.489561
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 128.222568
# ====> Epoch: 5 Average loss: 129.1340
# ====> Test set loss: 130.2880
# Train Epoch: 6 [0/60000 (0%)]	Loss: 126.836152
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 126.723301
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 129.612783
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 124.958311
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 122.721445
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 124.725645
# ====> Epoch: 6 Average loss: 128.7764
# ====> Test set loss: 130.0873
# Train Epoch: 7 [0/60000 (0%)]	Loss: 136.932178
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 132.387920
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 123.123564
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 123.743115
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 134.257012
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 126.109248
# ====> Epoch: 7 Average loss: 128.5078
# ====> Test set loss: 129.9243
# Train Epoch: 8 [0/60000 (0%)]	Loss: 120.620010
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 126.355566
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 124.399219
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 131.136846
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 128.521357
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 132.848359
# ====> Epoch: 8 Average loss: 128.1283
# ====> Test set loss: 129.6863
# Train Epoch: 9 [0/60000 (0%)]	Loss: 127.367539
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 126.693857
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 129.596660
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 134.936738
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 126.051777
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 131.009668
# ====> Epoch: 9 Average loss: 127.9105
# ====> Test set loss: 129.7719
# Train Epoch: 10 [0/60000 (0%)]	Loss: 129.483018
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 125.498037
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 124.773223
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 120.804395
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 127.979756
# Train Epoch: 10 [50000/60000 (83%)]	Loss:
# Train Epoch: 24 [20000/60000 (33%)]	Loss: 128.974912
# Train Epoch: 24 [30000/60000 (50%)]	Loss: 125.154434
# Train Epoch: 24 [40000/60000 (67%)]	Loss: 126.798809
# Train Epoch: 24 [50000/60000 (83%)]	Loss: 123.667461
# ====> Epoch: 24 Average loss: 124.8319
# ====> Test set loss: 128.2470
# Train Epoch: 25 [0/60000 (0%)]	Loss: 121.194922
# Train Epoch: 25 [10000/60000 (17%)]	Loss: 119.928691
# Train Epoch: 25 [20000/60000 (33%)]	Loss: 135.988418
# Train Epoch: 25 [30000/60000 (50%)]	Loss: 126.860469
# Train Epoch: 25 [40000/60000 (67%)]	Loss: 128.744795
# Train Epoch: 25 [50000/60000 (83%)]	Loss: 124.222109
# ====> Epoch: 25 Average loss: 124.7550
# ====> Test set loss: 128.6215
# Train Epoch: 26 [0/60000 (0%)]	Loss: 128.695654
# Train Epoch: 26 [10000/60000 (17%)]	Loss: 131.556484
# Train Epoch: 26 [20000/60000 (33%)]	Loss: 123.010527
# Train Epoch: 26 [30000/60000 (50%)]	Loss: 121.486602
# Train Epoch: 26 [40000/60000 (67%)]	Loss: 122.122734
# Train Epoch: 26 [50000/60000 (83%)]	Loss: 127.113945
# ====> Epoch: 26 Average loss: 124.5789
# ====> Test set loss: 128.0821
# Train Epoch: 27 [0/60000 (0%)]	Loss: 121.388730
# Train Epoch: 27 [10000/60000 (17%)]	Loss: 118.487451
# Train Epoch: 27 [20000/60000 (33%)]	Loss: 127.751191
# Train Epoch: 27 [30000/60000 (50%)]	Loss: 116.135996
# Train Epoch: 27 [40000/60000 (67%)]	Loss: 118.430723
# Train Epoch: 27 [50000/60000 (83%)]	Loss: 125.153594
# ====> Epoch: 27 Average loss: 124.4011
# ====> Test set loss: 128.6671
# Train Epoch: 28 [0/60000 (0%)]	Loss: 126.616807
# Train Epoch: 28 [10000/60000 (17%)]	Loss: 123.190361
# Train Epoch: 28 [20000/60000 (33%)]	Loss: 124.759902
# Train Epoch: 28 [30000/60000 (50%)]	Loss: 128.634443
# Train Epoch: 28 [40000/60000 (67%)]	Loss: 119.632881
# Train Epoch: 28 [50000/60000 (83%)]	Loss: 133.228906
# ====> Epoch: 28 Average loss: 124.4537
# ====> Test set loss: 128.5085
# Train Epoch: 29 [0/60000 (0%)]	Loss: 126.416611
# Train Epoch: 29 [10000/60000 (17%)]	Loss: 128.140801
# Train Epoch: 29 [20000/60000 (33%)]	Loss: 127.490156
# Train Epoch: 29 [30000/60000 (50%)]	Loss: 125.228506
# Train Epoch: 29 [40000/60000 (67%)]	Loss: 126.343799
# Train Epoch: 29 [50000/60000 (83%)]	Loss: 122.604600
# ====> Epoch: 29 Average loss: 124.3000
# ====> Test set loss: 128.1511
# Train Epoch: 30 [0/60000 (0%)]	Loss: 120.248340
# Train Epoch: 30 [10000/60000 (17%)]	Loss: 127.947500
# Train Epoch: 30 [20000/60000 (33%)]	Loss: 122.457588
# Train Epoch: 30 [30000/60000 (50%)]	Loss: 125.348994
# Train Epoch: 30 [40000/60000 (67%)]	Loss: 124.835254
# Train Epoch: 30 [50000/60000 (83%)]	Loss: 111.658818
# ====> Epoch: 30 Average loss: 124.1695
# ====> Test set loss: 127.8804
# Saved fc_vae_3d.pth

# %% [markdown]
# ## 4. Reconstruction Quality

# %%
vae.eval()
data, _ = next(iter(test_loader))
data = data[:10].to(device)
with torch.no_grad():
    recon, _, _ = vae(data)
recon = recon.view(-1, 1, 28, 28)

fig, axes = plt.subplots(2, 10, figsize=(15, 4))
for i in range(10):
    axes[0, i].imshow(data[i].cpu().squeeze(), cmap="gray"); axes[0, i].axis("off")
    axes[1, i].imshow(recon[i].cpu().squeeze(), cmap="gray"); axes[1, i].axis("off")

plt.suptitle("VAE reconstruction with 3-D bottleneck", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. The 3D Latent Space
#
# Encode the entire test set and plot the encoder means $\mu$ in 3D.

# %%
all_mu, all_labels = [], []
with torch.no_grad():
    for data, labels in test_loader:
        mu, _ = vae.encoder(data.to(device).view(-1, 784))
        all_mu.append(mu.cpu()); all_labels.append(labels)
all_mu = torch.cat(all_mu).numpy()
all_labels = torch.cat(all_labels).numpy()

for i in range(3):
    print(f"mu_{i+1}: range [{all_mu[:, i].min():.2f}, {all_mu[:, i].max():.2f}], "
          f"mean={all_mu[:, i].mean():.2f}, std={all_mu[:, i].std():.2f}")
# Out:
# mu_1: range [-3.89, 4.75], mean=0.04, std=1.03
# mu_2: range [-4.37, 3.74], mean=0.03, std=1.00
# mu_3: range [-3.55, 4.05], mean=-0.02, std=1.08

# %% [markdown]
# ## 6. Side-by-Side: AE vs VAE Latent Space
#
# Load the AE latents from `01_FC_Autoencoder_3D.ipynb` and plot both clouds with
# the same axis limits so the difference in scale and shape is obvious.

# %%
ae_data = np.load("latents_ae_3d.npz")
ae_z = ae_data["z"]
ae_labels = ae_data["labels"]

all_pts = np.vstack([ae_z, all_mu])
lo, hi = all_pts.min(), all_pts.max()

fig = plt.figure(figsize=(15, 7))
for k, (pts, labels, title) in enumerate(
    [(ae_z, ae_labels, "AE"), (all_mu, all_labels, "VAE")]
):
    ax = fig.add_subplot(1, 2, k + 1, projection="3d")
    sc = ax.scatter(pts[:, 0], pts[:, 1], pts[:, 2],
                    c=labels, cmap="tab10", s=3, alpha=0.6)
    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi); ax.set_zlim(lo, hi)
    ax.set_xlabel("$z_1$"); ax.set_ylabel("$z_2$"); ax.set_zlabel("$z_3$")
    ax.set_title(f"{title} latent space  (range x: [{pts[:,0].min():.1f}, {pts[:,0].max():.1f}])")
fig.suptitle("AE (no constraint) vs VAE (KL pulls toward unit Gaussian) — same axes", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Sampling: $z \sim \mathcal{N}(0, I)$
#
# Run the same Gaussian samples through both decoders.

# %%
# Reload the AE for the side-by-side decoder comparison
class FCAutoencoder(nn.Module):
    def __init__(self, latent_dim=3):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 256), nn.ReLU(),
            nn.Linear(256, 64), nn.ReLU(),
            nn.Linear(64, latent_dim),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 256), nn.ReLU(),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z).view(-1, 1, 28, 28), z

ae = FCAutoencoder(3).to(device)
ae.load_state_dict(torch.load("fc_autoencoder_3d.pth", map_location=device))
ae.eval()

torch.manual_seed(0)
N = 16
z = torch.randn(N, 3, device=device)
with torch.no_grad():
    ae_samples = ae.decoder(z).view(-1, 28, 28).cpu()
    vae_samples = vae.decoder(z).view(-1, 28, 28).cpu()

fig, axes = plt.subplots(2, N, figsize=(1.4 * N, 3))
for j in range(N):
    axes[0, j].imshow(ae_samples[j], cmap="gray", vmin=0, vmax=1); axes[0, j].axis("off")
    axes[1, j].imshow(vae_samples[j], cmap="gray", vmin=0, vmax=1); axes[1, j].axis("off")

fig.suptitle("Same $z \\sim \\mathcal{N}(0, I)$ through both decoders", fontsize=12)
plt.tight_layout()
plt.show()
